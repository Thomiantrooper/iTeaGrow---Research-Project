# %% [markdown]
# <a href="https://colab.research.google.com/github/Thomiantrooper/Car-game/blob/main/tea_leaf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Mon Jan 12 07:30:30 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   63C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !unzip raw_data.zip -d /content/dataset
# Out:
# Archive:  raw_data.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of raw_data.zip or
#         raw_data.zip.zip, and cannot find raw_data.zip.ZIP, period.

# %%
# !unzip raw_data.zip -d /content/dataset
# Out:
# Archive:  raw_data.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of raw_data.zip or
#         raw_data.zip.zip, and cannot find raw_data.zip.ZIP, period.

# %%
# !unzip tea-leaf-disease.v3-roboflow-instant-2--eval-.yolov8.zip -d /content/dataset
# Out:
# Archive:  tea-leaf-disease.v3-roboflow-instant-2--eval-.yolov8.zip
#   inflating: /content/dataset/README.dataset.txt
#   inflating: /content/dataset/README.roboflow.txt
#   inflating: /content/dataset/data.yaml
#    creating: /content/dataset/test/
#    creating: /content/dataset/test/images/
#  extracting: /content/dataset/test/images/IMG-20251122-WA0110_jpg.rf.096b1c847296199696166e58e6dcf741.jpg
#  extracting: /content/dataset/test/images/UNADJUSTEDNONRAW_thumb_180_jpg.rf.77b67a709be8f1f03d287ed21bbf5302.jpg
#  extracting: /content/dataset/test/images/UNADJUSTEDNONRAW_thumb_197_jpg.rf.13e7e4cadd5ab563a17f209ea186b9e9.jpg
#  extracting: /content/dataset/test/images/UNADJUSTEDNONRAW_thumb_1a6_jpg.rf.5a469875597a93c1833d32a191dd5b48.jpg
#  extracting: /content/dataset/test/images/UNADJUSTEDNONRAW_thumb_1b3_jpg.rf.550372162aa8b9abb5fa7c5ad6cc9306.jpg
#  extracting: /content/dataset/test/images/UNADJUSTEDNONRAW_thumb_1b4_jpg.rf.5378141183a8d9209fb52ca8b5e775b3.jpg
# ...

# %%
# !ls /content/dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install ultralytics roboflow opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 21.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 77.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 104.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
# !ls dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !ls dataset/train/images | wc -l
# Out:
# 299

# %%
# %%writefile dataset/data.yaml
# train: /content/dataset/train/images
# val: /content/dataset/valid/images
# test: /content/dataset/test/images
#
# nc: 3
# names: ['blister_blight', 'healthy', 'red_rust']
# Out:
# Overwriting dataset/data.yaml

# %%
# !cat dataset/data.yaml
# Out:
# train: /content/dataset/train/images
# val: /content/dataset/valid/images
# test: /content/dataset/test/images
#
# nc: 3
# names: ['blister_blight', 'healthy', 'red_rust']

# %%
from ultralytics import YOLO

model = YOLO("yolov8s.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(
    data="dataset/data.yaml",
    epochs=150,
    imgsz=640,
    batch=16,
    device=0,
    project="runs/detect",
    name="tea_leaf_gpu"
)
# Out:
# Ultralytics 8.3.252 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls runs/detect/tea_leaf_gpu/weights
# Out:
# ls: cannot access 'runs/detect/tea_leaf_gpu/weights': No such file or directory

# %%
# !ls runs/detect/tea_leaf_gpu/weights
# Out:
# ls: cannot access 'runs/detect/tea_leaf_gpu/weights': No such file or directory

# %%
# !ls /content/runs/detect/runs/detect/tea_leaf_gpu/weights
# Out:
# best.pt  last.pt

# %%
# !zip -r tea_leaf_model.zip /content/runs/detect/runs/detect/tea_leaf_gpu
# Out:
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/ (stored 0%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/train_batch2662.jpg (deflated 15%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/BoxF1_curve.png (deflated 12%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/labels.jpg (deflated 39%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/val_batch1_pred.jpg (deflated 18%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/confusion_matrix_normalized.png (deflated 28%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/val_batch0_pred.jpg (deflated 14%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/BoxP_curve.png (deflated 12%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/weights/ (stored 0%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/weights/best.pt (deflated 8%)
#   adding: content/runs/detect/runs/detect/tea_leaf_gpu/weights/last.pt (deflated 8%)
# ...
